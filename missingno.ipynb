# %% [markdown]
# <a href="https://colab.research.google.com/github/ngntrgduc/learning-python/blob/master/missingno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import missingno as msno
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
collisions = pd.read_csv("https://raw.githubusercontent.com/ResidentMario/missingno-data/master/nyc_collision_factors.csv")
collisions.sample(5)
# Out:
#             DATE      TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 3380  03/25/2016  22:10:00  BROOKLYN   11234.0  40.616295 -73.929899
# 6668  02/02/2016  09:50:00  BROOKLYN   11220.0  40.638153 -74.013962
# 987   11/22/2016  17:11:00  BROOKLYN   11218.0  40.640915 -73.973642
# 1245  11/15/2016  06:11:00    QUEENS   11106.0  40.763416 -73.928427
# 4005  02/17/2016  15:26:00  BROOKLYN   11214.0  40.598552 -73.997339
#
#                        LOCATION   ON STREET NAME CROSS STREET NAME  \
# 3380  (40.6162948, -73.9298992)  FLATBUSH AVENUE          AVENUE O
# 6668   (40.6381529, -74.013962)        60 STREET          6 AVENUE
# 987   (40.6409147, -73.9736422)    OCEAN PARKWAY          AVENUE C
# 1245  (40.7634163, -73.9284268)  CRESCENT STREET          BROADWAY
# 4005  (40.5985519, -73.9973389)      BAY PARKWAY       BATH AVENUE
#
#      OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 1  \
# 3380             NaN  ...  Failure to Yield Right-of-Way
# ...

# %%
# msno.matrix(collisions.sample(250))
# msno.matrix(collisions.sample(250), sparkline=False)
msno.matrix(collisions, sparkline=False, label_rotation=30, color=(0, 0, 0))
# Out:
# <Axes: >

# %%
# msno.bar(collisions.sample(1000))
msno.bar(collisions, color='C0')
# Out:
# <Axes: >

# %%
msno.heatmap(collisions)
# Out:
# <Axes: >

# %%
msno.dendrogram(collisions, orientation='right')
# Out:
# <Axes: >
