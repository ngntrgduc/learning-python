# %% [markdown]
# <a href="https://colab.research.google.com/github/ngntrgduc/learning-python/blob/master/missingno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import missingno as msno
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
collisions = pd.read_csv("https://raw.githubusercontent.com/ResidentMario/missingno-data/master/nyc_collision_factors.csv")
collisions.sample(5)
# Out:
#             DATE      TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 1316  04/16/2016  20:00:00  BROOKLYN   11233.0  40.677365 -73.907977
# 6872  04/14/2016  12:05:00    QUEENS   11418.0  40.702657 -73.817542
# 5418  01/11/2016  15:00:00    QUEENS   11412.0  40.705413 -73.780345
# 838   09/13/2016  12:09:00       NaN       NaN  40.843907 -73.927275
# 6840  04/20/2016  02:00:00    QUEENS   11355.0  40.757390 -73.813703
#
#                        LOCATION       ON STREET NAME CROSS STREET NAME  \
# 1316  (40.6773646, -73.9079765)      EASTERN PARKWAY   HERKIMER STREET
# 6872  (40.7026569, -73.8175422)  METROPOLITAN AVENUE   KEW GARDEN ROAD
# 5418  (40.7054135, -73.7803454)           180 STREET    LIBERTY AVENUE
# 838    (40.8439065, -73.927275)                  NaN               NaN
# 6840  (40.7573895, -73.8137033)      DELAWARE AVENUE        149 STREET
#
#      OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 1  \
# 1316             NaN  ...  Failure to Yield Right-of-Way
# 6872             NaN  ...  Failure to Yield Right-of-Way
# 5418             NaN  ...  Failure to Yield Right-of-Way
# 838              NaN  ...  Failure to Yield Right-of-Way
# 6840             NaN  ...  Failure to Yield Right-of-Way
#
#       CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 1316  Failure to Yield Right-of-Way                            NaN
# 6872  Failure to Yield Right-of-Way                            NaN
# 5418                            NaN                            NaN
# 838                     Unspecified                            NaN
# 6840                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 1316                            NaN                            NaN
# 6872                            NaN                            NaN
# 5418                            NaN                            NaN
# 838                             NaN                            NaN
# 6840                            NaN                            NaN
#
#       VEHICLE TYPE CODE 1 VEHICLE TYPE CODE 2 VEHICLE TYPE CODE 3  \
# 1316    PASSENGER VEHICLE   PASSENGER VEHICLE                 NaN
# 6872    PASSENGER VEHICLE   PASSENGER VEHICLE                 NaN
# 5418              UNKNOWN                 NaN                 NaN
# 838     PASSENGER VEHICLE                 NaN                 NaN
# 6840    PASSENGER VEHICLE                 NaN                 NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 1316                 NaN                 NaN
# 6872                 NaN                 NaN
# 5418                 NaN                 NaN
# 838                  NaN                 NaN
# 6840                 NaN                 NaN
#
# [5 rows x 26 columns]

# %%
# msno.matrix(collisions.sample(250))
msno.matrix(collisions.sample(250), sparkline=False)
# Out:
# <Axes: >

# %%
msno.bar(collisions.sample(1000), log=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/missingno/missingno.py:271: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels([int(n * len(df)) for n in ax1.get_yticks()], fontsize=fontsize)
# <Axes: >

# %%
msno.heatmap(collisions)
# Out:
# <Axes: >

# %%
msno.dendrogram(collisions, orientation='right')
# Out:
# <Axes: >
